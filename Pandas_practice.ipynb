# %% [markdown]
# <a href="https://colab.research.google.com/github/debanandasen/Tensorflow/blob/main/Pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas Pracice
# # This notebook offers a set of solutions to different tasks with pandas.

# %%
# import pandas
import pandas as pd

# %%
# Create a series of different colors
colours = pd.Series(["Red", "Blue", "White"])

# %%
# View the series
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# Create a series of different car types
cars = pd.Series(["BMW", "Toyota", "Honda"])

# %%
cars
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
car_data = pd.DataFrame({"Car Make": cars,
                         "Colours": colours})

# %%
cars
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
car_data
# Out:
#   Car Make Colours
# 0      BMW     Red
# 1   Toyota    Blue
# 2    Honda   White
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(car_data, *['Car Make'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
# ...

# %%
# Import "/content/car-sales.csv" and turn it into a DataFrame
car_sales = pd.read_csv("/content/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Find the different datatypes of the car dataFrame
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Odometer (KM)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
# Create a Series of different numbers and find thenmean of them
series = pd.Series([999,22203,43920])
series.mean()
# Out:
# 22374.0

# %%
series.sum()
# Out:
# 67122

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
# Create a crosstab
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()
# Out:
# <ipython-input-36-b0a0096139ad>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car_sales.groupby(["Make"]).mean()
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Imoport Matplotlib and create a plot of Odomter
# %matplotlib inline
import matplotlib.patches as plt
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
# Try to plot the Proce column using plot()
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-3d3a618d7f86> in <cell line: 2>()
#       1 # Try to plot the Proce column using plot()
# ----> 2 car_sales["Price"].plot()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
# Remove the punctuation from price column
car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "")
# Out:
# <ipython-input-41-4f07fe03675c>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "")

# %%
car_sales["Price"]
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: object

# %%
car_sales["Price"]  = car_sales["Price"].str[:-2]

# %%
car_sales["Price"]
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: object

# %%
car_sales["Price"] = car_sales['Price'].astype(int)

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
# Import car sales with Missing data
car_sales_missing = pd.read_csv("/content/car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales["seats"] = 5
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats
# 0  Toyota  White         150043      4   4000      5
# 1   Honda    Red          87899      4   5000      5
# 2  Toyota   Blue          32549      3   7000      5
# 3     BMW  Black          11179      5  22000      5
# 4  Nissan  White         213095      4   3500      5
# 5  Toyota  Green          99213      4   4500      5
# 6   Honda   Blue          45698      4   7500      5
# 7   Honda   Blue          54738      4   7000      5
# 8  Toyota  White          60000      4   6250      5
# 9  Nissan  White          31600      4   9700      5

# %%
car_sales["Price per KM"] = car_sales["Price"] / car_sales["Odometer (KM)"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  Price per KM
# 0  Toyota  White         150043      4   4000      5      0.026659
# 1   Honda    Red          87899      4   5000      5      0.056883
# 2  Toyota   Blue          32549      3   7000      5      0.215060
# 3     BMW  Black          11179      5  22000      5      1.967976
# 4  Nissan  White         213095      4   3500      5      0.016425
# 5  Toyota  Green          99213      4   4500      5      0.045357
# 6   Honda   Blue          45698      4   7500      5      0.164121
# 7   Honda   Blue          54738      4   7000      5      0.127882
# 8  Toyota  White          60000      4   6250      5      0.104167
# 9  Nissan  White          31600      4   9700      5      0.306962

# %%
# Shuffle the data using sample() with the frac pramater set to 1
car_sales_sampled = car_sales_missing = car_sales.sample(frac=1)
car_sales_sampled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  Price per KM
# 5  Toyota  Green          99213      4   4500      5      0.045357
# 2  Toyota   Blue          32549      3   7000      5      0.215060
# 6   Honda   Blue          45698      4   7500      5      0.164121
# 4  Nissan  White         213095      4   3500      5      0.016425
# 3     BMW  Black          11179      5  22000      5      1.967976
# 9  Nissan  White          31600      4   9700      5      0.306962
# 7   Honda   Blue          54738      4   7000      5      0.127882
# 1   Honda    Red          87899      4   5000      5      0.056883
# 0  Toyota  White         150043      4   4000      5      0.026659
# 8  Toyota  White          60000      4   6250      5      0.104167

# %%
# Reset the indexes of the shuffled DataFrame
car_sales_sampled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors  Price  seats  Price per KM
# 0      5  Toyota  Green          99213      4   4500      5      0.045357
# 1      2  Toyota   Blue          32549      3   7000      5      0.215060
# 2      6   Honda   Blue          45698      4   7500      5      0.164121
# 3      4  Nissan  White         213095      4   3500      5      0.016425
# 4      3     BMW  Black          11179      5  22000      5      1.967976
# 5      9  Nissan  White          31600      4   9700      5      0.306962
# 6      7   Honda   Blue          54738      4   7000      5      0.127882
# 7      1   Honda    Red          87899      4   5000      5      0.056883
# 8      0  Toyota  White         150043      4   4000      5      0.026659
# 9      8  Toyota  White          60000      4   6250      5      0.104167

# %%
# Change the Odometer values from Kilometer to miles using Lambda Function
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x:1/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  seats  Price per KM
# 0  Toyota  White          0.625      4   4000      5      0.026659
# 1   Honda    Red          0.625      4   5000      5      0.056883
# 2  Toyota   Blue          0.625      3   7000      5      0.215060
# 3     BMW  Black          0.625      5  22000      5      1.967976
# 4  Nissan  White          0.625      4   3500      5      0.016425
# 5  Toyota  Green          0.625      4   4500      5      0.045357
# 6   Honda   Blue          0.625      4   7500      5      0.164121
# 7   Honda   Blue          0.625      4   7000      5      0.127882
# 8  Toyota  White          0.625      4   6250      5      0.104167
# 9  Nissan  White          0.625      4   9700      5      0.306962
